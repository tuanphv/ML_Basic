# %% [markdown]
# # Bài tập thực hành 1: Xây dựng mô hình từ giải thuật SVM trên dữ liệu bệnh tiểu đường.
# Dữ liệu lấy từ [🍬Diabetes : EDA |🌲Random Forest🌲 + HP⚙️](https://www.kaggle.com/code/tumpanjawat/diabetes-eda-random-forest-hp)

# %% [markdown]
# ## Chuẩn bị

# %% [markdown]
# ### Khai báo thư viện cần thiết

# %%
import numpy as np
import pandas as pd
from IPython import display
from sklearn.model_selection import train_test_split
from sklearn import svm

# %% [markdown]
# ### Tải dữ liệu

# %%
diabetes_data = pd.read_csv('../data/diabetes_prediction_dataset.csv')

# %% [markdown]
# ## Sơ lược về dữ liệu

# %% [markdown]
# ### Head, Tail

# %%
print("Head 5")
display.display(diabetes_data.head())
print("Tail 5")
display.display(diabetes_data.tail())
# Out:
# Head 5
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0
# Tail 5
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# ...

# %% [markdown]
# ### Shape, info

# %%
print("Shape:", diabetes_data.shape)
print("Info:")
diabetes_data.info()
# Out:
# Shape: (100000, 9)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ### Mean, std, min, max, count

# %%
diabetes_data.describe().T
# Out:
#                         count        mean        std    min     25%     50%  \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
# diabetes             100000.0    0.085000   0.278883   0.00    0.00    0.00
#
#                         75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %% [markdown]
# ## Làm sạch dữ liệu

# %% [markdown]
# ### Kiểm tra NaN, Null

# %%
diabetes_data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# ### Kiểm tra duplicate

# %%
diabetes_data[diabetes_data.duplicated()]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 2756     Male  80.0             0              0         No Info  27.32
# 3272   Female  80.0             0              0         No Info  27.32
# 3418   Female  19.0             0              0         No Info  27.32
# 3939   Female  78.0             1              0          former  27.32
# 3960     Male  47.0             0              0         No Info  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99980  Female  52.0             0              0           never  27.32
# 99985    Male  25.0             0              0         No Info  27.32
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99995  Female  80.0             0              0         No Info  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 2756           6.6                  159         0
# ...

# %% [markdown]
# Xóa các dòng bị trùng

# %%
diabetes_data = diabetes_data.drop_duplicates()
print("Duplicate rows after removing:", diabetes_data.duplicated().sum())
print("Duplicate removed. New shape:", diabetes_data.shape)
# Out:
# Duplicate rows after removing: 0
# Duplicate removed. New shape: (96146, 9)

# %% [markdown]
# ### One-Hot: gender, smoking_history

# %%
diabetes_data = pd.get_dummies(diabetes_data, columns=['gender', 'smoking_history'], drop_first=True)
display.display(diabetes_data)
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99994  36.0             0              0  24.60          4.8
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  gender_Male  gender_Other  \
# 0                      140         0        False         False
# 1                       80         0        False         False
# ...

# %% [markdown]
# ## Chia dữ liệu train & test

# %%
data = diabetes_data.drop(columns=['diabetes'])
target = diabetes_data['diabetes']
display.display(data)
display.display(target)
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99994  36.0             0              0  24.60          4.8
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  gender_Male  gender_Other  \
# 0                      140        False         False
# 1                       80        False         False
# 2                      158         True         False
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Huấn luyện mô hình SVM

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Đánh giá độ chính xác

# %%
train_acc = clf.score(X_train,y_train)
val_acc = clf.score(X_test,y_test)
print('Training accuracy: {}'.format(train_acc))
print('Validation accuracy: {}'.format(val_acc))
# Out:
# Training accuracy: 0.9453429715533829
# Validation accuracy: 0.9449817992719709

# %% [markdown]
# ## Tìm tham số tối ưu

# %%
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
best_svm = None
best_val_acc = -1
best_kernel = None

for i in range(4):
    clf = svm.SVC(kernel=kernels[i], probability=True)
    clf.fit(X_train, y_train)
    tmp_val_acc = clf.score(X_test, y_test)
    if (tmp_val_acc > best_val_acc):
        best_val_acc = tmp_val_acc
    best_svm = clf
    best_kernel = kernels[i]

print("Best validation accuracy : {} with kernel: {}".format(best_val_acc, best_kernel))
# Out:
# Best validation accuracy : 0.9576183047321893 with kernel: sigmoid

# %% [markdown]
# # Kết thúc
